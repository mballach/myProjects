# %%
import os
import pandas as pd
import numpy as np
from pybaseball import pitching_stats

# %%
# Setting parameters for date search
START = 2015
END = 2022

# %%
if os.path.exists("pitching.csv"):
    pitching = pd.read_csv("pitching.csv", index_col=0)
else:
    pitching = pitching_stats(START, END)
    pitching.to_csv("pitching.csv")

# %%
pitching = pitching.groupby("IDfg",group_keys=False).filter(lambda x: x.shape[0]>1)

# %%
pitching
# Out:
#       IDfg  Season             Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 2    10954    2018     Jacob deGrom    NYM   30  10   9  9.0  1.70  32  ...
# 10    2036    2015  Clayton Kershaw    LAD   27  16   7  8.6  2.13  33  ...
# 75   10603    2017       Chris Sale    BOS   28  17   8  7.6  2.90  32  ...
# 32   13125    2019      Gerrit Cole    HOU   28  20   5  7.5  2.50  33  ...
# 36    3137    2018     Max Scherzer    WSN   33  18   7  7.5  2.53  33  ...
# ..     ...     ...              ...    ...  ...  ..  ..  ...   ...  ..  ...
# 311  15467    2022   Marco Gonzales    SEA   30  10  15  0.1  4.13  32  ...
# 434   7593    2021     Jordan Lyles    TEX   30  10  13  0.1  5.15  32  ...
# 451  15474    2018    Lucas Giolito    CHW   23  10  13  0.1  6.13  32  ...
# 452  15440    2020     Matthew Boyd    DET   29   3   7 -0.1  6.71  12  ...
# 450   7059    2016    James Shields  - - -   34   6  19 -1.0  5.85  33  ...
#
#        LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 2    11.1       20    0.039  112.9      148     0.287     515  0.164  0.315
# 10    8.9       15    0.028  113.3      132     0.244     542  0.164  0.323
# 75   15.0       27    0.055  112.7      149     0.303     492  0.183  0.332
# 32   14.0       25    0.057  115.2      156     0.355     440  0.171  0.339
# 36   20.6       34    0.068  111.1      159     0.316     503  0.165  0.327
# ..    ...      ...      ...    ...      ...       ...     ...    ...    ...
# 311  14.5       45    0.072  111.2      215     0.345     623  0.151  0.235
# 434  15.3       51    0.091  115.5      233     0.416     560  0.158  0.263
# 451  13.3       39    0.072  114.4      201     0.369     545  0.171  0.254
# 452  15.4       20    0.109  110.8       68     0.370     184  0.138  0.263
# 450  12.8       46    0.077  115.8      198     0.332     597  0.153  0.245
#
#      xERA
# 2     NaN
# 10    NaN
# 75    NaN
# 32    NaN
# 36    NaN
# ..    ...
# 311   NaN
# 434   NaN
# 451   NaN
# 452   NaN
# 450   NaN
#
# [367 rows x 334 columns]

# %%
def next_season(player):
    player = player.sort_values("Season")
    player["Next_WAR"] = player ["WAR"].shift(-1)
    return player

pitching = pitching.groupby("IDfg",group_keys=False).apply(next_season)

# %%
pitching
# Out:
#       IDfg  Season            Name Team  Age   W   L  WAR   ERA   G  ...  \
# 319    375    2015   Bartolo Colon  NYM   42  14  13  2.5  4.16  33  ...
# 175    375    2016   Bartolo Colon  NYM   43  15   8  2.4  3.43  34  ...
# 408    404    2015     CC Sabathia  NYY   34   6  10  1.2  4.73  29  ...
# 267    404    2016     CC Sabathia  NYY   35   9  12  2.6  3.91  30  ...
# 111   1118    2015   Marco Estrada  TOR   31  13   8  1.8  3.13  34  ...
# ..     ...     ...             ...  ...  ...  ..  ..  ...   ...  ..  ...
# 135  19374    2019  Walker Buehler  LAD   24  14   4  5.1  3.26  30  ...
# 29   19374    2021  Walker Buehler  LAD   26  16   4  5.5  2.47  33  ...
# 137  19427    2019    Shane Bieber  CLE   24  15   8  5.5  3.28  34  ...
# 0    19427    2020    Shane Bieber  CLE   25   8   1  3.2  1.63  12  ...
# 70   19427    2022    Shane Bieber  CLE   27  13   8  4.9  2.88  31  ...
#
#      Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xERA  \
# 319       33    0.051  113.4      227     0.349     651  0.212  0.276   NaN
# 175       29    0.046  117.1      232     0.369     628  0.210  0.265   NaN
# 408       23    0.043  115.3      166     0.311     533  0.185  0.276   NaN
# 267       22    0.041  111.1      146     0.269     542  0.176  0.275   NaN
# 111       24    0.045  112.8      164     0.307     534  0.147  0.246   NaN
# ..       ...      ...    ...      ...       ...     ...    ...    ...   ...
# 135       21    0.044  111.3      174     0.364     478  0.180  0.301   NaN
# 29        37    0.068  114.4      201     0.369     545  0.181  0.296   NaN
# 137       41    0.074  113.5      231     0.417     554  0.185  0.325   NaN
# 0         11    0.072  112.9       66     0.431     153  0.167  0.338   NaN
# 70        40    0.072  110.2      238     0.429     555  0.175  0.314   NaN
#
#      Next_WAR
# 319       2.4
# 175       NaN
# 408       2.6
# 267       NaN
# 111       2.7
# ..        ...
# 135       5.5
# 29        NaN
# 137       3.2
# 0         4.9
# 70        NaN
#
# [367 rows x 335 columns]

# %%
null_count = pitching.isnull().sum()

# %%
complete_cols = list(pitching.columns[null_count==0])

# %%
pitching = pitching[complete_cols + ["Next_WAR"]].copy()

# %%
pitching.isnull().sum()
# Out:
# IDfg          0
# Season        0
# Name          0
# Team          0
# Age           0
#            ...
# HardHit%      0
# Events        0
# CStr%         0
# CSW%          0
# Next_WAR    112
# Length: 161, dtype: int64

# %%
pitching.dtypes[pitching.dtypes=="object"]
# Out:
# Name       object
# Team       object
# Dollars    object
# Age Rng    object
# dtype: object

# %%
del pitching["Age Rng"]
del pitching["Dollars"]

# %%
pitching["team_code"]= pitching["Team"].astype("category").cat.codes

# %%
pitching_full = pitching.copy()
pitching = pitching.dropna().copy()

# %%
pitching
# Out:
#       IDfg  Season            Name Team  Age   W   L  WAR   ERA   G  ...  \
# 319    375    2015   Bartolo Colon  NYM   42  14  13  2.5  4.16  33  ...
# 408    404    2015     CC Sabathia  NYY   34   6  10  1.2  4.73  29  ...
# 111   1118    2015   Marco Estrada  TOR   31  13   8  1.8  3.13  34  ...
# 182   1118    2016   Marco Estrada  TOR   32   9   9  2.7  3.48  29  ...
# 266   1245    2015     R.A. Dickey  TOR   40  11  11  1.8  3.91  33  ...
# ..     ...     ...             ...  ...  ...  ..  ..  ...   ...  ..  ...
# 52   19291    2020      Zac Gallen  ARI   24   3   2  1.4  2.75  12  ...
# 24   19361    2021   Corbin Burnes  MIL   26  11   5  7.5  2.43  28  ...
# 135  19374    2019  Walker Buehler  LAD   24  14   4  5.1  3.26  30  ...
# 137  19427    2019    Shane Bieber  CLE   24  15   8  5.5  3.28  34  ...
# 0    19427    2020    Shane Bieber  CLE   25   8   1  3.2  1.63  12  ...
#
#      Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 319       33    0.051  113.4      227     0.349     651  0.212  0.276
# 408       23    0.043  115.3      166     0.311     533  0.185  0.276
# 111       24    0.045  112.8      164     0.307     534  0.147  0.246
# 182       33    0.067  113.2      154     0.315     489  0.167  0.276
# 266       26    0.038  110.9      208     0.303     686  0.163  0.254
# ..       ...      ...    ...      ...       ...     ...    ...    ...
# 52        13    0.071  109.5       59     0.324     182  0.195  0.316
# 24        12    0.031  114.2      117     0.305     383  0.172  0.338
# 135       21    0.044  111.3      174     0.364     478  0.180  0.301
# 137       41    0.074  113.5      231     0.417     554  0.185  0.325
# 0         11    0.072  112.9       66     0.431     153  0.167  0.338
#
#      Next_WAR  team_code
# 319       2.4         18
# 408       2.6         19
# 111       2.7         29
# 182       2.6         29
# 266       0.8         29
# ..        ...        ...
# 52        4.3          1
# 24        4.6         16
# 135       5.5         14
# 137       3.2          8
# 0         4.9          8
#
# [255 rows x 160 columns]

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = Ridge(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs=SequentialFeatureSelector(rr,n_features_to_select=10,direction = "forward", cv=split, n_jobs=8)

# %%
removed_columns = ["Next_WAR", "Name", "Team", "IDfg", "Season"]
selected_columns = pitching.columns[~pitching.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
pitching.loc[:,selected_columns]=scaler.fit_transform(pitching[selected_columns])
# Out:
# /var/folders/0l/x2w1pf9j5t740pwr1j9z0sq00000gn/T/ipykernel_95707/3991961105.py:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   pitching.loc[:,selected_columns]=scaler.fit_transform(pitching[selected_columns])

# %%
sfs.fit(pitching[selected_columns],pitching["Next_WAR"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=Ridge(alpha=1), n_features_to_select=10,
#                           n_jobs=8)

# %%
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['WAR',
#  'IFH',
#  'HR/FB',
#  'tERA',
#  'FBv',
#  'xFIP-',
#  'BB%',
#  'Zone% (sc)',
#  'Hard%',
#  'Pull%+']

# %%
def backtest(data,model,predictors,start=3,step=1):
    all_predictions=[]
    
    years=sorted(data["Season"].unique())
    
    for i in range(start, len(years),step):
        current_year=years[i]
        train=data[data["Season"]<current_year]
        test=data[data["Season"]==current_year]
        
        model.fit(train[predictors],train["Next_WAR"])
        
        preds=model.predict(test[predictors])
        preds=pd.Series(preds,index=test.index)
        combined=pd.concat([test["Next_WAR"],preds],axis=1)
        combined.columns=["actual","prediction"]
        
        all_predictions.append(combined)
        
    return pd.concat(all_predictions)

# %%
predictions = backtest(pitching, rr, predictors)

# %%
predictions
# Out:
#      actual  prediction
# 127     5.3    2.394819
# 324     2.1    1.798846
# 73      3.0    3.836649
# 337     1.8    2.683320
# 36      6.5    5.132629
# ..      ...         ...
# 392     6.3    3.457844
# 269     4.4    3.981179
# 122     5.7    4.027255
# 328     1.4    2.718562
# 24      4.6    4.879301
#
# [117 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 2.4385903598074226

# %%
pitching["Next_WAR"].describe()
# Out:
# count    255.000000
# mean       3.065490
# std        1.693871
# min       -1.000000
# 25%        1.900000
# 50%        2.800000
# 75%        4.150000
# max        9.000000
# Name: Next_WAR, dtype: float64

# %%
2.4385903598074217 ** 0.5
# Out:
# 1.5615986551631702

# %%
def player_history(df):
    df = df.sort_values("Season")
    
    df["player_season"] = range(0,df.shape[0])
    
    df["war_corr"] = list(df[["player_season","WAR"]].expanding().corr().loc[(slice(None),"player_season"),"WAR"])
    
    df ["war_corr"].fillna(0,inplace=True)
    
    df["war_diff"]=df["WAR"]/df["WAR"].shift(1)
    df["war_diff"].fillna(1,inplace=True)
    df["war_diff"][df["war_diff"]==np.inf] = 1
    
    return df

pitching = pitching.groupby("IDfg",group_keys=False).apply(player_history)

# %%
def group_averages(df):
    return df["WAR"]/df["WAR"].mean()

pitching["war_season"] = pitching.groupby("Season", group_keys=False).apply(group_averages)

# %%
new_predictors = predictors + ["player_season", "war_season"]

# %%
predictions = backtest(pitching,rr, new_predictors)

# %%
mean_squared_error(predictions["actual"],predictions["prediction"])
# Out:
# 2.468286370804577

# %% [markdown]
# I have learned that, apparently, adding player history makes the model worse for pitchers. Pitching WAR is better explained by prior season stats without adding player history and WAR information.
